# %% [markdown]
# <a href="https://colab.research.google.com/github/Melanee-Melanee/OCR/blob/main/TrainYolov8CustomDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train Yolov8 object detection on a custom dataset (Alpaca detection) via Python script (this method couldn't detect)
#
#
# References:
#
# https://www.youtube.com/watch?v=m9fH9OWn8YM
#
# https://github.com/computervisioneng/train-yolov8-custom-dataset-step-by-step-guide
#
# https://github.com/ultralytics/ultralytics
#
# Annotation tool:
#
# https://www.cvat.ai/

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/ComputerVisionDeveloper/TrainYolov8CustomDataset/'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 5.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=5)  # train the model
# metrics = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#methods for loading custom image:
#https://github.com/ultralytics/ultralytics/issues/4969

# %%
# Perform inference on the image with the following arguments
# model.predict('alpaaa.jpg', save=True, imgsz=640, conf=0.5)

# %%
#Inference with Custom Model (inputing custom image)
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/alpaaa.jpg
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/alpaaa.jpg: 480x640 (no detections), 176.2ms
# Speed: 10.6ms preprocess, 176.2ms inference, 36.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Visualising our detection

# %%
import cv2
from ultralytics import YOLO

# Load the custom YOLOv8 model
model = YOLO('/content/runs/detect/train2/weights/best.pt')  # Replace with the path to your trained model

# %%
# Load an image
image_path = '/content/alpaaa.jpg'  # Replace with the path to your custom image
image = cv2.imread(image_path)
# Perform inference
results = model(image)
# Out:
# 0: 480x640 (no detections), 202.2ms
# Speed: 4.9ms preprocess, 202.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Process and visualize results
for result in results:
    boxes = result.boxes.xyxy  # get boxes coordinates in xyxy format
    confidences = result.boxes.conf  # get confidence scores
    classes = result.boxes.cls  # get class IDs

    for box, confidence, cls in zip(boxes, confidences, classes):
        x1, y1, x2, y2 = map(int, box)
        label = f'{model.names[int(cls)]}: {confidence:.2f}'

        # Draw the bounding box and label on the image
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the image
from google.colab.patches import cv2_imshow

# After drawing bounding boxes
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
#if you get UTF-8 error on your Goole colab:

# import locale
# print(locale.getpreferredencoding())
# def getpreferredencoding(do_setlocale = True):
#     return "UTF-8"
# locale.getpreferredencoding = getpreferredencoding

# %%
# !pwd
# Out:
# /content

# %%
#coping model in our goole colab
# !scp -r /content/runs '/content/gdrive/My Drive/ComputerVisionDeveloper/TrainYolov8CustomDataset'

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/ComputerVisionDeveloper/TrainYolov8CustomDataset

# %%
# %cd /content/gdrive/MyDrive/ComputerVisionDeveloper/TrainYolov8CustomDataset
# Out:
# /content/gdrive/MyDrive/ComputerVisionDeveloper/TrainYolov8CustomDataset

# %%
#from IPython.display import display, Image
#Image(filename='runs/detect/train2/confusion_matrix.png', width=600)

# import glob
# from IPython.display import Image, display

# for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
#       display(Image(filename=image_path, width=600))
#       print("\n")

# %%
import cv2
im2 = cv2.imread("alpaaa.jpg")
results = model.predict(source=im2, save=True, save_txt=True) # save predictions as labels
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 (no detections), 459.4ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 (no detections), 259.5ms
# Speed: 14.5ms preprocess, 359.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train2
# 0 label saved to runs/detect/train2/labels
