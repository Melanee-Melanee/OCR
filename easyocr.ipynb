# %% [markdown]
# <a href="https://colab.research.google.com/github/Melanee-Melanee/OCR/blob/main/easyocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install easyocr
# !pip install boto3
# !pip install Pillow

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/Persiancuneiform1/text1.png')
imgplot = plt.imshow(img)
plt.show()

# %%
from PIL import Image
from easyocr import Reader
import boto3
import easyocr

# %%
reader = easyocr.Reader(['en'])

text = ''
results = reader.readtext('/content/drive/MyDrive/Persiancuneiform1/text1.png')
for result in results:
  text = text + result[1] +  ' '

text = text[:-1]
print(text)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# This is the first line of this text example. This is the second line of the same text.
